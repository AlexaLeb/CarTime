# %%
# NYC Weather Data via Meteostat (using NOAA data)
import requests
import pandas as pd

token = "ozFjosloVwEurlSqyGOZLcvRZGtAEFWm"

url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data"

params = {
    "datasetid": "GHCND",
    "stationid": "GHCND:USW00094728",
    "startdate": "2023-01-01",
    "enddate": "2023-01-31",
    "limit": 1000,
    "units": "metric"
}

headers = {
    "token": token
}

res = requests.get(url, params=params, headers=headers)
data = res.json()

# Преобразуем в DataFrame
records = data.get("results", [])
df = pd.DataFrame(records)
print(df.head())
# Out:
#                   date datatype            station attributes    value
# 0  2023-01-01T00:00:00     ADPT  GHCND:USW00094728       ,,W,     39.0
# 1  2023-01-01T00:00:00     ASLP  GHCND:USW00094728       ,,W,  10125.0
# 2  2023-01-01T00:00:00     ASTP  GHCND:USW00094728       ,,W,  10071.0
# 3  2023-01-01T00:00:00     AWBT  GHCND:USW00094728       ,,W,     78.0
# 4  2023-01-01T00:00:00     AWND  GHCND:USW00094728       ,,W,      2.2

# %%
# Отфильтруем нужные показатели
needed_codes = ["TMAX", "TMIN", "PRCP"]

df_filtered = df[df["datatype"].isin(needed_codes)].copy()

# Значения делим на 10
df_filtered["value"] = df_filtered["value"] / 10

# Сводим в табличку с колонками
pivot = df_filtered.pivot_table(
    index="date",
    columns="datatype",
    values="value"
)

print(pivot.head())
# Out:
# datatype             PRCP  TMAX  TMIN
# date
# 2023-01-01T00:00:00  0.00  1.28  0.94
# 2023-01-02T00:00:00  0.05  1.33  0.94
# 2023-01-03T00:00:00  1.07  1.44  0.83
# 2023-01-04T00:00:00  0.05  1.89  0.94
# 2023-01-05T00:00:00  0.03  1.00  0.67

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# NOAA API токен
token = "ozFjosloVwEurlSqyGOZLcvRZGtAEFWm"

# URL и настройки
url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data"
station_id = "GHCND:USW00094728"  # NYC Central Park

headers = {"token": token}

# Генерация месяцев 2025 года
def get_month_ranges(year):
    ranges = []
    for month in range(1, 13):
        start = datetime(year, month, 1)
        if month == 12:
            end = datetime(year + 1, 1, 1) - timedelta(days=1)
        else:
            end = datetime(year, month + 1, 1) - timedelta(days=1)
        ranges.append((start.strftime("%Y-%m-%d"), end.strftime("%Y-%m-%d")))
    return ranges

# Скачиваем по каждому месяцу
all_data = []

for start_date, end_date in get_month_ranges(2025):
    print(f"📅 Загружаем данные: {start_date} — {end_date}")
    params = {
        "datasetid": "GHCND",
        "stationid": station_id,
        "startdate": start_date,
        "enddate": end_date,
        "limit": 1000,
        "units": "metric"
    }

    res = requests.get(url, params=params, headers=headers)
    
    if res.status_code != 200:
        print(f"⚠️ Ошибка при загрузке {start_date} — {end_date}: {res.status_code}")
        continue

    records = res.json().get("results", [])
    all_data.extend(records)

# В DataFrame
df = pd.DataFrame(all_data)

# Преобразуем дату в datetime
df["date"] = pd.to_datetime(df["date"])



# 1. Убедимся, что дата в нужном формате
df['date'] = pd.to_datetime(df['date'])

# 2. Разворачиваем таблицу: каждая дата и станция — одна строка
df_wide = df.pivot_table(
    index=['date', 'station'],
    columns='datatype',
    values='value',
    aggfunc='first'  # если вдруг есть дубликаты
).reset_index()

# 3. Опционально: убрать имя оси столбцов (datatype)
df_wide.columns.name = None

# 4. Смотрим результат
print(df_wide.head())

# Сохраняем в CSV
df_wide.to_csv("nyc_weather_2025.csv", index=False)

print("✅ Файл сохранен!")
# Out:
# 📅 Загружаем данные: 2025-01-01 — 2025-01-31
# 📅 Загружаем данные: 2025-02-01 — 2025-02-28
# 📅 Загружаем данные: 2025-03-01 — 2025-03-31
# 📅 Загружаем данные: 2025-04-01 — 2025-04-30
# 📅 Загружаем данные: 2025-05-01 — 2025-05-31
# 📅 Загружаем данные: 2025-06-01 — 2025-06-30
# 📅 Загружаем данные: 2025-07-01 — 2025-07-31
# 📅 Загружаем данные: 2025-08-01 — 2025-08-31
# 📅 Загружаем данные: 2025-09-01 — 2025-09-30
# 📅 Загружаем данные: 2025-10-01 — 2025-10-31
# 📅 Загружаем данные: 2025-11-01 — 2025-11-30
# 📅 Загружаем данные: 2025-12-01 — 2025-12-31
#         date            station  AWND    PGTM  PRCP  SNOW  SNWD  TMAX  TMIN  \
# 0 2025-01-01  GHCND:USW00094728   3.7  1606.0   0.0   0.0   0.0  10.6   3.9
# 1 2025-01-02  GHCND:USW00094728   4.3  1508.0   0.0   0.0   0.0   6.1   0.6
# 2 2025-01-03  GHCND:USW00094728   3.5  1439.0   0.0   0.0   0.0   3.9  -0.5
# 3 2025-01-04  GHCND:USW00094728   4.5  1302.0   0.0   0.0   0.0   0.6  -2.1
# 4 2025-01-05  GHCND:USW00094728   3.8  1614.0   0.0   0.0   0.0   0.6  -2.1
#
#     WDF2   WDF5  WSF2  WSF5  WT01  WT02  WT03  WT06  WT08
# 0  280.0  270.0   9.8  16.1   NaN   NaN   NaN   NaN   NaN
# 1  280.0  230.0   8.9  17.4   NaN   NaN   NaN   NaN   NaN
# 2  230.0  230.0   6.7  12.1   NaN   NaN   NaN   NaN   NaN
# 3  270.0  320.0   9.8  17.9   NaN   NaN   NaN   NaN   NaN
# 4  310.0  310.0   8.1  13.4   NaN   NaN   NaN   NaN   NaN
# ✅ Файл сохранен!

# %%
df_wide
# Out:
#           date            station  AWND    PGTM  PRCP  SNOW  SNWD  TMAX  TMIN  \
# 0   2025-01-01  GHCND:USW00094728   3.7  1606.0   0.0   0.0   0.0  10.6   3.9
# 1   2025-01-02  GHCND:USW00094728   4.3  1508.0   0.0   0.0   0.0   6.1   0.6
# 2   2025-01-03  GHCND:USW00094728   3.5  1439.0   0.0   0.0   0.0   3.9  -0.5
# 3   2025-01-04  GHCND:USW00094728   4.5  1302.0   0.0   0.0   0.0   0.6  -2.1
# 4   2025-01-05  GHCND:USW00094728   3.8  1614.0   0.0   0.0   0.0   0.6  -2.1
# ..         ...                ...   ...     ...   ...   ...   ...   ...   ...
# 188 2025-07-08  GHCND:USW00094728   1.4     NaN   2.3   0.0   0.0  33.9  22.8
# 189 2025-07-09  GHCND:USW00094728   1.0     NaN   1.3   0.0   0.0  32.2  22.8
# 190 2025-07-10  GHCND:USW00094728   0.8     NaN   4.6   0.0   0.0  28.9  21.1
# 191 2025-07-11  GHCND:USW00094728   1.1     NaN   0.0   0.0   0.0  28.9  22.8
# 192 2025-07-12  GHCND:USW00094728   0.9  1411.0   0.0   0.0   0.0  28.3  23.3
#
#       WDF2   WDF5  WSF2  WSF5  WT01  WT02  WT03  WT06  WT08
# 0    280.0  270.0   9.8  16.1   NaN   NaN   NaN   NaN   NaN
# 1    280.0  230.0   8.9  17.4   NaN   NaN   NaN   NaN   NaN
# 2    230.0  230.0   6.7  12.1   NaN   NaN   NaN   NaN   NaN
# 3    270.0  320.0   9.8  17.9   NaN   NaN   NaN   NaN   NaN
# 4    310.0  310.0   8.1  13.4   NaN   NaN   NaN   NaN   NaN
# ..     ...    ...   ...   ...   ...   ...   ...   ...   ...
# 188  220.0  210.0   6.3  12.1   1.0   NaN   1.0   NaN   NaN
# 189  240.0  240.0   4.5   8.1   1.0   NaN   NaN   NaN   NaN
# 190   60.0  240.0   3.6   5.4   1.0   NaN   NaN   NaN   NaN
# 191  130.0  130.0   4.0   7.2   NaN   NaN   NaN   NaN   NaN
# 192  120.0  130.0   4.0   8.5   NaN   NaN   NaN   NaN   NaN
#
# [193 rows x 18 columns]

# %%
# %pip install pyarrow==15.0.2
import pyarrow
import pandas as pd
# Out:
# Collecting pyarrow==15.0.2
#   Downloading pyarrow-15.0.2-cp39-cp39-macosx_10_15_x86_64.whl (27.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 85.0 kB/s eta 0:00:0000:0100:10
# Requirement already satisfied: numpy<2,>=1.16.6 in ./opt/anaconda3/lib/python3.9/site-packages (from pyarrow==15.0.2) (1.21.5)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-15.0.2
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4_/s5nq1m4x3x766j84pv1dwbz80000gn/T/ipykernel_17993/1235893141.py in <module>
#      11
#      12 # Посмотреть первые строки
# ---> 13 print(df1.head())
#      14
#      15 # Посмотреть список всех колонок
#
# NameError: name 'df1' is not defined

# %%
# Путь к файлу (поменяй на нужный)
file_path = 'data/nyc/green_tripdata_2025-01.parquet'

# Чтение parquet-файла
df1 = pd.read_parquet(file_path)

# Посмотреть первые строки
print(df1.head())

# Посмотреть список всех колонок
print(df1.columns)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
# 1         2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
# 2         2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
# 3         2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
# 4         2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            75           235              1.0           5.93
# 1         1.0           166            75              1.0           1.32
# 2         5.0           171            73              1.0           0.41
# 3         1.0            74           223              1.0           4.12
# 4         1.0            66           158              1.0           4.71
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0        24.70  ...      0.5        6.80          0.00        NaN
# 1         8.60  ...      0.5        0.00          0.00        NaN
# 2        25.55  ...      0.0        0.00          0.00        NaN
# 3        21.20  ...      0.5        6.13          6.94        NaN
# 4        33.80  ...      0.5        7.81          0.00        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         34.00           1.0        1.0
# 1                    1.0         11.10           2.0        1.0
# 2                    1.0         26.55           2.0        2.0
# 3                    1.0         36.77           1.0        1.0
# 4                    1.0         46.86           1.0        1.0
#
#    congestion_surcharge  cbd_congestion_fee
# 0                  0.00                 0.0
# 1                  0.00                 0.0
# 2                  0.00                 0.0
# 3                  0.00                 0.0
# 4                  2.75                 0.0
#
# [5 rows x 21 columns]
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge',
#        'cbd_congestion_fee'],
#       dtype='object')

# %%
import os
# Путь к папке с parquet-файлами
folder = "Data/nyc/"

# Найти все parquet-файлы
files = [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith('.parquet')]

print(f"Найдено файлов: {len(files)}")

# Чтение всех файлов и склейка
frames = []
for file in files:
    try:
        print(f"Читаю файл: {file}")
        df = pd.read_parquet(file, engine='pyarrow')
        frames.append(df)
    except Exception as e:
        print(f"❌ Ошибка при чтении файла {file}: {e}")

# Объединяем в один DataFrame
if frames:
    df_all = pd.concat(frames, ignore_index=True)
    print(f"✅ Всего строк в объединенном датасете: {len(df_all)}")
else:
    df_all = pd.DataFrame()
    print("⚠️ Нет данных для склейки.")

# Сохраняем в один parquet (или CSV)
output_file = os.path.join(folder, "green_tripdata_merged.parquet")
df_all.to_parquet(output_file, engine='pyarrow', index=False)
print(f"✅ Данные сохранены в {output_file}")

# Если хочешь сохранить в CSV:
# df_all.to_csv(os.path.join(folder, "green_tripdata_merged.csv"), index=False)
# Out:
# Найдено файлов: 16
# Читаю файл: Data/nyc/fhv_tripdata_2025-02.parquet
# Читаю файл: Data/nyc/fhvhv_tripdata_2025-04.parquet
# Читаю файл: Data/nyc/yellow_tripdata_2025-02.parquet
# Читаю файл: Data/nyc/yellow_tripdata_2025-03.parquet
# Читаю файл: Data/nyc/green_tripdata_2022-01.parquet
# Читаю файл: Data/nyc/green_tripdata_2025-03.parquet
# Читаю файл: Data/nyc/fhv_tripdata_2025-03.parquet
# Читаю файл: Data/nyc/yellow_tripdata_2022-01.parquet
# Читаю файл: Data/nyc/yellow_tripdata_2025-01.parquet
# Читаю файл: Data/nyc/green_tripdata_2025-01.parquet
# Читаю файл: Data/nyc/fhv_tripdata_2025-01.parquet
# Читаю файл: Data/nyc/green_tripdata_2022-02.parquet
# Читаю файл: Data/nyc/fhvhv_tripdata_2025-03.parquet
# Читаю файл: Data/nyc/green_tripdata_2025-04.parquet
# Читаю файл: Data/nyc/fhv_tripdata_2025-04.parquet
# Читаю файл: Data/nyc/yellow_tripdata_2025-04.parquet
# ✅ Всего строк в объединенном датасете: 65566563
# ✅ Данные сохранены в Data/nyc/green_tripdata_merged.parquet

# %%
df_all.to_csv(os.path.join(folder, "green_tripdata_merged.csv"), index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/4_/s5nq1m4x3x766j84pv1dwbz80000gn/T/ipykernel_17993/3689505289.py in <module>
# ----> 1 df_all.to_csv(os.path.join(folder, "green_tripdata_merged.csv"), index=False)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1178             formatter=self.fmt,
#    1179         )
# -> 1180         csv_formatter.save()
#    1181
#    1182         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     259             )
#     260
# --> 261             self._save()
#     262
#     263     def _save(self) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save(self)
#     264         if self._need_to_save_header:
#     265             self._save_header()
# --> 266         self._save_body()
#     267
#     268     def _save_header(self) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save_body(self)
#     302             if start_i >= end_i:
#     303                 break
# --> 304             self._save_chunk(start_i, end_i)
#     305
#     306     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     309         df = self.obj.iloc[slicer]
#     310
# --> 311         res = df._mgr.to_native_types(**self._number_format)
#     312         data = [res.iget_values(i) for i in range(len(res.items))]
#     313
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in to_native_types(self, **kwargs)
#     471         in formatting (repr / csv).
#     472         """
# --> 473         return self.apply("to_native_types", **kwargs)
#     474
#     475     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in to_native_types(self, na_rep, quoting, **kwargs)
#     632     def to_native_types(self, na_rep="nan", quoting=None, **kwargs):
#     633         """convert to our native types format"""
# --> 634         result = to_native_types(self.values, na_rep=na_rep, quoting=quoting, **kwargs)
#     635         return self.make_block(result)
#     636
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in to_native_types(values, na_rep, quoting, float_format, decimal, **kwargs)
#    2199
#    2200             if not quoting:
# -> 2201                 values = values.astype(str)
#    2202             else:
#    2203                 values = np.array(values, dtype="object")
#
# KeyboardInterrupt:

# %%
df_all.head()
# Out:
#   dispatching_base_num     pickup_datetime    dropOff_datetime  PUlocationID  \
# 0               B00014 2025-02-01 00:00:00 2025-02-01 00:33:00           NaN
# 1               B00053 2025-02-01 00:24:00 2025-02-01 00:39:00           NaN
# 2               B00112 2025-02-01 00:15:13 2025-02-01 00:22:34           NaN
# 3               B00112 2025-02-01 00:28:02 2025-02-01 00:35:54           NaN
# 4               B00221 2025-02-01 00:12:26 2025-02-01 00:18:11           NaN
#
#    DOlocationID  SR_Flag Affiliated_base_number hvfhs_license_num  \
# 0           NaN      NaN                 B00014               NaN
# 1           NaN      NaN                 B00053               NaN
# 2          14.0      NaN                 B00112               NaN
# 3          14.0      NaN                 B00112               NaN
# 4         167.0      NaN                 B00221               NaN
#
#   originating_base_num request_datetime  ... mta_tax tip_amount  tolls_amount  \
# 0                  NaN              NaT  ...     NaN        NaN           NaN
# 1                  NaN              NaT  ...     NaN        NaN           NaN
# 2                  NaN              NaT  ...     NaN        NaN           NaN
# 3                  NaN              NaT  ...     NaN        NaN           NaN
# 4                  NaN              NaT  ...     NaN        NaN           NaN
#
#    improvement_surcharge  total_amount  Airport_fee  lpep_pickup_datetime  \
# 0                    NaN           NaN          NaN                   NaT
# 1                    NaN           NaN          NaN                   NaT
# 2                    NaN           NaN          NaN                   NaT
# 3                    NaN           NaN          NaN                   NaT
# 4                    NaN           NaN          NaN                   NaT
#
#    lpep_dropoff_datetime  ehail_fee  trip_type
# 0                    NaT        NaN        NaN
# 1                    NaT        NaN        NaN
# 2                    NaT        NaN        NaN
# 3                    NaT        NaN        NaN
# 4                    NaT        NaN        NaN
#
# [5 rows x 50 columns]

# %%
df_all.columns
# Out:
# Index(['dispatching_base_num', 'pickup_datetime', 'dropOff_datetime',
#        'PUlocationID', 'DOlocationID', 'SR_Flag', 'Affiliated_base_number',
#        'hvfhs_license_num', 'originating_base_num', 'request_datetime',
#        'on_scene_datetime', 'dropoff_datetime', 'PULocationID', 'DOLocationID',
#        'trip_miles', 'trip_time', 'base_passenger_fare', 'tolls', 'bcf',
#        'sales_tax', 'congestion_surcharge', 'airport_fee', 'tips',
#        'driver_pay', 'shared_request_flag', 'shared_match_flag',
#        'access_a_ride_flag', 'wav_request_flag', 'wav_match_flag',
#        'cbd_congestion_fee', 'VendorID', 'tpep_pickup_datetime',
#        'tpep_dropoff_datetime', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount', 'Airport_fee',
#        'lpep_pickup_datetime', 'lpep_dropoff_datetime', 'ehail_fee',
#        'trip_type'],
#       dtype='object')

# %%
import pandas as pd

# 1. Прочитать датасет
df = pd.read_parquet("data/nyc/green_tripdata_merged.parquet")
print("Форма до изменений:", df.shape)

# 2. Создаём столбец pickup_datetime
pickup_cols = [
    "pickup_datetime",
    "tpep_pickup_datetime",
    "lpep_pickup_datetime"
]

# Найдём первый непустой pickup_datetime для каждой строки
# Если колонка отсутствует в датафрейме — не берём её
existing_cols = [col for col in pickup_cols if col in df.columns]

if not existing_cols:
    raise Exception("Нет колонок начала поездки в датасете!")

df["pickup_datetime"] = df[existing_cols].bfill(axis=1).iloc[:, 0]

# Приведём к datetime
df["pickup_datetime"] = pd.to_datetime(df["pickup_datetime"], errors='coerce')

# 3. Удаляем все колонки конца поездки
drop_cols = [
    "dropOff_datetime",
    "tpep_dropoff_datetime",
    "lpep_dropoff_datetime",
    "dropoff_datetime"
]
drop_cols = [col for col in drop_cols if col in df.columns]

df.drop(columns=drop_cols, inplace=True)

# 4. Создаём колонку с часом поездки
df["pickup_hour"] = df["pickup_datetime"].dt.hour

# 5. Проверим результат
print("Форма после изменений:", df.shape)
print(df.head())

# 6. Сохраним результат
df.to_parquet("green_tripdata_cleaned.parquet", index=False)
print("✅ Датасет сохранён в green_tripdata_cleaned.parquet!")
# Out:
# Форма до изменений: (65566563, 50)
# Форма после изменений: (65566563, 47)
#   dispatching_base_num     pickup_datetime  PUlocationID  DOlocationID  \
# 0               B00014 2025-02-01 00:00:00           NaN           NaN
# 1               B00053 2025-02-01 00:24:00           NaN           NaN
# 2               B00112 2025-02-01 00:15:13           NaN          14.0
# 3               B00112 2025-02-01 00:28:02           NaN          14.0
# 4               B00221 2025-02-01 00:12:26           NaN         167.0
#
#    SR_Flag Affiliated_base_number hvfhs_license_num originating_base_num  \
# 0      NaN                 B00014              None                 None
# 1      NaN                 B00053              None                 None
# 2      NaN                 B00112              None                 None
# 3      NaN                 B00112              None                 None
# 4      NaN                 B00221              None                 None
#
#   request_datetime on_scene_datetime  ...  mta_tax  tip_amount  tolls_amount  \
# 0              NaT               NaT  ...      NaN         NaN           NaN
# 1              NaT               NaT  ...      NaN         NaN           NaN
# 2              NaT               NaT  ...      NaN         NaN           NaN
# 3              NaT               NaT  ...      NaN         NaN           NaN
# 4              NaT               NaT  ...      NaN         NaN           NaN
#
#    improvement_surcharge  total_amount  Airport_fee  lpep_pickup_datetime  \
# 0                    NaN           NaN          NaN                   NaT
# 1                    NaN           NaN          NaN                   NaT
# 2                    NaN           NaN          NaN                   NaT
# 3                    NaN           NaN          NaN                   NaT
# 4                    NaN           NaN          NaN                   NaT
#
#    ehail_fee  trip_type  pickup_hour
# 0       None        NaN            0
# 1       None        NaN            0
# 2       None        NaN            0
# 3       None        NaN            0
# 4       None        NaN            0
#
# [5 rows x 47 columns]
# ✅ Датасет сохранён в green_tripdata_cleaned.parquet!

# %%
import pandas as pd

# путь к твоему parquet-файлу
file_path = "Data/nyc/green_tripdata_cleaned.parquet"

# читаем датасет
df = pd.read_parquet(file_path)

# список колонок для удаления
cols_to_drop = [
    "dispatching_base_num", "originating_base_num", "Affiliated_base_number",
    "hvfhs_license_num", "request_datetime", "on_scene_datetime",
    "dropOff_datetime", "trip_miles", "shared_request_flag",
    "shared_match_flag", "access_a_ride_flag", "wav_request_flag",
    "wav_match_flag", "SR_Flag", "PGTM", "WDF2", "WDF5", "WSF2", "WSF5"
]

# удаляем, если такие колонки существуют
df = df.drop(columns=[col for col in cols_to_drop if col in df.columns])

print("✅ Ненужные колонки удалены!")
print(df.head())

# сохраним обратно в parquet или csv
df.to_parquet("Data/nyc/green_tripdata_cleaned.parquet", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/4_/s5nq1m4x3x766j84pv1dwbz80000gn/T/ipykernel_22542/3296027304.py in <module>
#      17
#      18 # удаляем, если такие колонки существуют
# ---> 19 df = df.drop(columns=[col for col in cols_to_drop if col in df.columns])
#      20
#      21 print("✅ Ненужные колонки удалены!")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4348
#    4349         bm_axis = self.ndim - axis_num - 1
# -> 4350         new_mgr = self._mgr.reindex_indexer(
#    4351             new_axis,
#    4352             indexer,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     680
#     681         if axis == 0:
# --> 682             new_blocks = self._slice_take_blocks_ax0(
#     683                 indexer,
#     684                 fill_value=fill_value,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     839                             blocks.append(nb)
#     840                     else:
# --> 841                         nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     842                         blocks.append(nb)
#     843
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1137             allow_fill = True
#    1138
# -> 1139         new_values = algos.take_nd(
#    1140             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1141         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/array_algos/take.py in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     115
#     116     arr = np.asarray(arr)
# --> 117     return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     118
#     119
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/array_algos/take.py in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     161         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162     )
# --> 163     func(arr, indexer, out, fill_value)
#     164
#     165     if flip_order:
#
# KeyboardInterrupt:

# %%
df.shape
# Out:
# (65566563, 32)

# %%
import pandas as pd

# загружаем твой датасет
file = 'Data/nyc/green_tripdata_cleaned.parquet'

df = pd.read_parquet(file)

# создаем новый столбец pickup_location_id:
# - сначала берем PULocationID, если он не пустой
# - если пустой → берем PUlocationID
df["pickup_location_id"] = df["PULocationID"].fillna(df["PUlocationID"])

# то же самое для dropoff_location_id
df["dropoff_location_id"] = df["DOLocationID"].fillna(df["DOlocationID"])

# убираем исходные 4 колонки
df.drop(columns=["PULocationID", "PUlocationID", "DOLocationID", "DOlocationID"], inplace=True)

df
# Out:
#              pickup_datetime  trip_time  base_passenger_fare  tolls  bcf  \
# 0        2025-02-01 00:00:00        NaN                  NaN    NaN  NaN
# 1        2025-02-01 00:24:00        NaN                  NaN    NaN  NaN
# 2        2025-02-01 00:15:13        NaN                  NaN    NaN  NaN
# 3        2025-02-01 00:28:02        NaN                  NaN    NaN  NaN
# 4        2025-02-01 00:12:26        NaN                  NaN    NaN  NaN
# ...                      ...        ...                  ...    ...  ...
# 65566558 2025-04-30 23:37:25        NaN                  NaN    NaN  NaN
# 65566559 2025-04-30 23:53:37        NaN                  NaN    NaN  NaN
# 65566560 2025-04-30 23:31:55        NaN                  NaN    NaN  NaN
# 65566561 2025-04-30 23:27:36        NaN                  NaN    NaN  NaN
# 65566562 2025-04-30 23:05:47        NaN                  NaN    NaN  NaN
#
#           sales_tax  congestion_surcharge  airport_fee  tips  driver_pay  ...  \
# 0               NaN                   NaN          NaN   NaN         NaN  ...
# 1               NaN                   NaN          NaN   NaN         NaN  ...
# 2               NaN                   NaN          NaN   NaN         NaN  ...
# 3               NaN                   NaN          NaN   NaN         NaN  ...
# 4               NaN                   NaN          NaN   NaN         NaN  ...
# ...             ...                   ...          ...   ...         ...  ...
# 65566558        NaN                   NaN          NaN   NaN         NaN  ...
# 65566559        NaN                   NaN          NaN   NaN         NaN  ...
# 65566560        NaN                   NaN          NaN   NaN         NaN  ...
# 65566561        NaN                   NaN          NaN   NaN         NaN  ...
# 65566562        NaN                   NaN          NaN   NaN         NaN  ...
#
#           tolls_amount  improvement_surcharge total_amount  Airport_fee  \
# 0                  NaN                    NaN          NaN          NaN
# 1                  NaN                    NaN          NaN          NaN
# 2                  NaN                    NaN          NaN          NaN
# 3                  NaN                    NaN          NaN          NaN
# 4                  NaN                    NaN          NaN          NaN
# ...                ...                    ...          ...          ...
# 65566558           0.0                    1.0         5.07          NaN
# 65566559           0.0                    1.0        25.75          NaN
# 65566560           0.0                    1.0         3.81          NaN
# 65566561           0.0                    1.0        25.16          NaN
# 65566562           0.0                    1.0         4.99          NaN
#
#           lpep_pickup_datetime  ehail_fee trip_type  pickup_hour  \
# 0                          NaT       None       NaN            0
# 1                          NaT       None       NaN            0
# 2                          NaT       None       NaN            0
# 3                          NaT       None       NaN            0
# 4                          NaT       None       NaN            0
# ...                        ...        ...       ...          ...
# 65566558                   NaT       None       NaN           23
# 65566559                   NaT       None       NaN           23
# 65566560                   NaT       None       NaN           23
# 65566561                   NaT       None       NaN           23
# 65566562                   NaT       None       NaN           23
#
#           pickup_location_id  dropoff_location_id
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                 14.0
# 3                        NaN                 14.0
# 4                        NaN                167.0
# ...                      ...                  ...
# 65566558                48.0                243.0
# 65566559               234.0                142.0
# 65566560                68.0                 45.0
# 65566561               186.0                141.0
# 65566562               158.0                164.0
#
# [65566563 rows x 32 columns]

# %%
df.to_parquet("Data/nyc/green_tripdata_cleaned.parquet", index=False)

# %%
df
# Out:
#              pickup_datetime  trip_time  base_passenger_fare  tolls  bcf  \
# 0        2025-02-01 00:00:00        NaN                  NaN    NaN  NaN
# 1        2025-02-01 00:24:00        NaN                  NaN    NaN  NaN
# 2        2025-02-01 00:15:13        NaN                  NaN    NaN  NaN
# 3        2025-02-01 00:28:02        NaN                  NaN    NaN  NaN
# 4        2025-02-01 00:12:26        NaN                  NaN    NaN  NaN
# ...                      ...        ...                  ...    ...  ...
# 65566558 2025-04-30 23:37:25        NaN                  NaN    NaN  NaN
# 65566559 2025-04-30 23:53:37        NaN                  NaN    NaN  NaN
# 65566560 2025-04-30 23:31:55        NaN                  NaN    NaN  NaN
# 65566561 2025-04-30 23:27:36        NaN                  NaN    NaN  NaN
# 65566562 2025-04-30 23:05:47        NaN                  NaN    NaN  NaN
#
#           sales_tax  congestion_surcharge  airport_fee  tips  driver_pay  ...  \
# 0               NaN                   NaN          NaN   NaN         NaN  ...
# 1               NaN                   NaN          NaN   NaN         NaN  ...
# 2               NaN                   NaN          NaN   NaN         NaN  ...
# 3               NaN                   NaN          NaN   NaN         NaN  ...
# 4               NaN                   NaN          NaN   NaN         NaN  ...
# ...             ...                   ...          ...   ...         ...  ...
# 65566558        NaN                   NaN          NaN   NaN         NaN  ...
# 65566559        NaN                   NaN          NaN   NaN         NaN  ...
# 65566560        NaN                   NaN          NaN   NaN         NaN  ...
# 65566561        NaN                   NaN          NaN   NaN         NaN  ...
# 65566562        NaN                   NaN          NaN   NaN         NaN  ...
#
#           tolls_amount  improvement_surcharge total_amount  Airport_fee  \
# 0                  NaN                    NaN          NaN          NaN
# 1                  NaN                    NaN          NaN          NaN
# 2                  NaN                    NaN          NaN          NaN
# 3                  NaN                    NaN          NaN          NaN
# 4                  NaN                    NaN          NaN          NaN
# ...                ...                    ...          ...          ...
# 65566558           0.0                    1.0         5.07          NaN
# 65566559           0.0                    1.0        25.75          NaN
# 65566560           0.0                    1.0         3.81          NaN
# 65566561           0.0                    1.0        25.16          NaN
# 65566562           0.0                    1.0         4.99          NaN
#
#           lpep_pickup_datetime  ehail_fee trip_type  pickup_hour  \
# 0                          NaT       None       NaN            0
# 1                          NaT       None       NaN            0
# 2                          NaT       None       NaN            0
# 3                          NaT       None       NaN            0
# 4                          NaT       None       NaN            0
# ...                        ...        ...       ...          ...
# 65566558                   NaT       None       NaN           23
# 65566559                   NaT       None       NaN           23
# 65566560                   NaT       None       NaN           23
# 65566561                   NaT       None       NaN           23
# 65566562                   NaT       None       NaN           23
#
#           pickup_location_id  dropoff_location_id
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                 14.0
# 3                        NaN                 14.0
# 4                        NaN                167.0
# ...                      ...                  ...
# 65566558                48.0                243.0
# 65566559               234.0                142.0
# 65566560                68.0                 45.0
# 65566561               186.0                141.0
# 65566562               158.0                164.0
#
# [65566563 rows x 32 columns]

# %%
# Преобразуем pickup_datetime в datetime
df["pickup_datetime"] = pd.to_datetime(df["pickup_datetime"])

# Извлекаем дату и час
df["pickup_date"] = df["pickup_datetime"].dt.date
df["pickup_hour"] = df["pickup_datetime"].dt.hour

# Группирующие ключи
group_cols = ["pickup_location_id", "pickup_date", "pickup_hour"]

# Оставляем только числовые колонки
numeric_cols = df.select_dtypes(include=["number"]).columns.tolist()

# Исключаем ключи из агрегируемых колонок
numeric_cols = [c for c in numeric_cols if c not in group_cols]

# Формируем словарь агрегаций
agg_dict = {col: "mean" for col in numeric_cols}

# Добавим count поездок
agg_dict["pickup_datetime"] = "count"

# Агрегируем
agg_df = (
    df
    .groupby(group_cols)
    .agg(agg_dict)
    .reset_index()
)

# Переименуем колонку count
agg_df = agg_df.rename(columns={"pickup_datetime": "ride_count"})

print("✅ Итоговый агрегированный DataFrame:")
print(agg_df.head())

# Сохраняем результат
agg_df.to_csv("green_tripdata_aggregated.csv", index=False)
print("✅ Файл green_tripdata_aggregated.csv сохранен.")
# Out:
# ✅ Итоговый агрегированный DataFrame:
#    pickup_location_id pickup_date  pickup_hour  trip_time  \
# 0                 1.0  2022-01-01            4        NaN
# 1                 1.0  2022-01-01            5        NaN
# 2                 1.0  2022-01-01            7        NaN
# 3                 1.0  2022-01-01           10        NaN
# 4                 1.0  2022-01-01           11        NaN
#
#    base_passenger_fare  tolls  bcf  sales_tax  congestion_surcharge  \
# 0                  NaN    NaN  NaN        NaN                   0.0
# 1                  NaN    NaN  NaN        NaN                   0.0
# 2                  NaN    NaN  NaN        NaN                   0.0
# 3                  NaN    NaN  NaN        NaN                   0.0
# 4                  NaN    NaN  NaN        NaN                   0.0
#
#    airport_fee  ...  extra  mta_tax  tip_amount  tolls_amount  \
# 0          0.0  ...    0.0      0.0        0.00          0.00
# 1          0.0  ...    0.0      0.0       10.00          0.00
# 2          0.0  ...    0.0      0.0       11.03          0.00
# 3          0.0  ...    0.0      0.0        0.00         18.75
# 4          0.0  ...    0.0      0.0        2.50          0.00
#
#    improvement_surcharge  total_amount  Airport_fee  trip_type  \
# 0                    0.3         40.30          NaN        NaN
# 1                    0.3        105.30          NaN        NaN
# 2                    0.3        107.83          NaN        NaN
# 3                    0.3         98.05          NaN        NaN
# 4                    0.3        105.30          NaN        NaN
#
#    dropoff_location_id  ride_count
# 0                  1.0           1
# 1                  1.0           1
# 2                  1.0           2
# 3                  1.0           1
# 4                  1.0           2
#
# [5 rows x 29 columns]
# ✅ Файл green_tripdata_aggregated.csv сохранен.

# %%
agg_df.describe()
# Out:
#        pickup_location_id    pickup_hour      trip_time  base_passenger_fare  \
# count       731727.000000  731727.000000  368645.000000        368645.000000
# mean           135.980493      11.852963    1075.012252            25.034043
# std             76.386939       6.690104     286.764673             9.213515
# min              1.000000       0.000000       1.000000            -5.910000
# 25%             70.000000       6.000000     906.917241            19.448687
# 50%            138.000000      12.000000    1043.865385            22.678113
# 75%            204.000000      18.000000    1197.365297            28.106582
# max            265.000000      23.000000    7489.500000           415.220000
#
#                tolls            bcf      sales_tax  congestion_surcharge  \
# count  368645.000000  368645.000000  368645.000000         611287.000000
# mean        1.012104       0.625903       2.117467              0.898329
# std         1.388191       0.236062       0.725290              1.053914
# min         0.000000       0.000000       0.000000              0.000000
# 25%         0.284296       0.484833       1.698049              0.000000
# 50%         0.648000       0.566026       1.970548              0.248418
# 75%         1.248150       0.701104       2.363333              2.329852
# max        39.730000      10.455000      37.125000              2.750000
#
#          airport_fee           tips  ...          extra        mta_tax  \
# count  432817.000000  368645.000000  ...  539524.000000  539524.000000
# mean        0.149796       0.929753  ...       0.524170       0.472277
# std         0.327768       1.012837  ...       0.880901       0.124744
# min         0.000000       0.000000  ...      -3.250000      -0.250000
# 25%         0.000000       0.295297  ...       0.000000       0.487179
# 50%         0.029297       0.675278  ...       0.000000       0.500000
# 75%         0.148810       1.257387  ...       0.793919       0.500000
# max         5.000000      50.000000  ...      11.000000      10.666667
#
#           tip_amount   tolls_amount  improvement_surcharge   total_amount  \
# count  539524.000000  539524.000000          539524.000000  539524.000000
# mean        1.678624       0.708208               0.771031      27.439769
# std         3.002394       1.820118               0.327294      20.573412
# min         0.000000       0.000000               0.000000     -39.500000
# 25%         0.000000       0.000000               0.500000      18.105000
# 50%         0.838750       0.000000               0.984962      22.956181
# 75%         2.482950       0.301739               1.000000      31.570000
# max       250.000000     101.780000               1.000000    5155.930385
#
#          Airport_fee     trip_type  dropoff_location_id     ride_count
# count  304528.000000  76810.000000        730909.000000  731727.000000
# mean        0.041589      1.091875           141.289651      81.282772
# std         0.246830      0.268890            40.554882     135.051656
# min         0.000000      1.000000             1.000000       1.000000
# 25%         0.000000      1.000000           120.036585       4.000000
# 50%         0.000000      1.000000           144.785714      26.000000
# 75%         0.000000      1.000000           163.449102     105.000000
# max         4.250000      2.000000           265.000000    2289.000000
#
# [8 rows x 28 columns]

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# NOAA API токен
token = "ozFjosloVwEurlSqyGOZLcvRZGtAEFWm"

headers = {"token": token}

# --- Получаем список станций в NYC ---
url_stations = "https://www.ncei.noaa.gov/cdo-web/api/v2/stations"
params_stations = {
    "datasetid": "GHCND",
    "extent": "40.5,-74.3,40.9,-73.7",  # рамка вокруг NYC
    "limit": 1000,
}
res = requests.get(url_stations, params=params_stations, headers=headers)
stations = res.json().get("results", [])

df_stations = pd.DataFrame(stations)
print("✅ Найдено станций:", len(df_stations))
print(df_stations[["id", "name"]])

# --- Функция дат ---
def get_month_ranges(year):
    ranges = []
    for month in range(1, 13):
        start = datetime(year, month, 1)
        if month == 12:
            end = datetime(year + 1, 1, 1) - timedelta(days=1)
        else:
            end = datetime(year, month + 1, 1) - timedelta(days=1)
        ranges.append((start.strftime("%Y-%m-%d"), end.strftime("%Y-%m-%d")))
    return ranges

# --- Скачиваем данные для всех станций ---
url_data = "https://www.ncei.noaa.gov/cdo-web/api/v2/data"

all_data = []

for station_id in df_stations["id"]:
    for start_date, end_date in get_month_ranges(2025):
        print(f"🔎 Скачиваем {station_id}: {start_date} — {end_date}")
        
        params_data = {
            "datasetid": "GHCND",
            "stationid": station_id,
            "startdate": start_date,
            "enddate": end_date,
            "limit": 1000,
            "units": "metric"
        }
        
        res = requests.get(url_data, params=params_data, headers=headers)
        
        if res.status_code != 200:
            print(f"⚠️ Ошибка {res.status_code} для станции {station_id} ({start_date} — {end_date})")
            continue
        
        records = res.json().get("results", [])
        all_data.extend(records)

# --- Преобразуем в таблицу ---
df = pd.DataFrame(all_data)
print("✅ Загружено строк:", len(df))

if not df.empty:
    df["date"] = pd.to_datetime(df["date"])

    df_wide = df.pivot_table(
        index=["date", "station"],
        columns="datatype",
        values="value",
        aggfunc="first"
    ).reset_index()

    df_wide.columns.name = None
    df_wide.to_csv("nyc_weather_allstations_2025.csv", index=False)
    print("✅ Данные сохранены в nyc_weather_allstations_2025.csv")

else:
    print("⚠️ Данных нет.")
# Out:
# ✅ Найдено станций: 99
#                    id                                 name
# 0   GHCND:US1NJBG0011        NORTH ARLINGTON 0.7 NE, NJ US
# 1   GHCND:US1NJBG0012             WOOD RIDGE 0.6 SE, NJ US
# 2   GHCND:US1NJBG0013              RUTHERFORD 1.2 N, NJ US
# 3   GHCND:US1NJBG0015       NORTH ARLINGTON 0.7 WNW, NJ US
# 4   GHCND:US1NJBG0018        PALISADES PARK 0.2 WNW, NJ US
# ..                ...                                  ...
# 94  GHCND:USW00014786  NEW YORK FLOYD BENNETT FIELD, NY US
# 95  GHCND:USW00054743     CALDWELL ESSEX CO AIRPORT, NJ US
# 96  GHCND:USW00094728          NY CITY CENTRAL PARK, NY US
# 97  GHCND:USW00094741             TETERBORO AIRPORT, NJ US
# 98  GHCND:USW00094789     JFK INTERNATIONAL AIRPORT, NY US
#
# [99 rows x 2 columns]
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-01-01 — 2025-01-31
# ⚠️ Ошибка 503 для станции GHCND:US1NJBG0011 (2025-01-01 — 2025-01-31)
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-05-01 — 2025-05-31
# ⚠️ Ошибка 503 для станции GHCND:US1NJBG0011 (2025-05-01 — 2025-05-31)
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJBG0011: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJBG0012: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJBG0013: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-07-01 — 2025-07-31
# ⚠️ Ошибка 503 для станции GHCND:US1NJBG0015 (2025-07-01 — 2025-07-31)
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-10-01 — 2025-10-31
# ⚠️ Ошибка 503 для станции GHCND:US1NJBG0015 (2025-10-01 — 2025-10-31)
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJBG0015: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-04-01 — 2025-04-30
# ⚠️ Ошибка 503 для станции GHCND:US1NJBG0018 (2025-04-01 — 2025-04-30)
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJBG0018: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJBG0033: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJBG0064: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJBG0065: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0004: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0010: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-03-01 — 2025-03-31
# ⚠️ Ошибка 503 для станции GHCND:US1NJES0011 (2025-03-01 — 2025-03-31)
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0011: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0015: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-03-01 — 2025-03-31
# ⚠️ Ошибка 503 для станции GHCND:US1NJES0018 (2025-03-01 — 2025-03-31)
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0018: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0019: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-01-01 — 2025-01-31
# ⚠️ Ошибка 503 для станции GHCND:US1NJES0020 (2025-01-01 — 2025-01-31)
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-04-01 — 2025-04-30
# ⚠️ Ошибка 503 для станции GHCND:US1NJES0020 (2025-04-01 — 2025-04-30)
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0020: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0021: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-08-01 — 2025-08-31
# ⚠️ Ошибка 503 для станции GHCND:US1NJES0024 (2025-08-01 — 2025-08-31)
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-11-01 — 2025-11-30
# ⚠️ Ошибка 503 для станции GHCND:US1NJES0024 (2025-11-01 — 2025-11-30)
# 🔎 Скачиваем GHCND:US1NJES0024: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0029: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-07-01 — 2025-07-31
# ⚠️ Ошибка 503 для станции GHCND:US1NJES0031 (2025-07-01 — 2025-07-31)
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0031: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-04-01 — 2025-04-30
# ⚠️ Ошибка 503 для станции GHCND:US1NJES0033 (2025-04-01 — 2025-04-30)
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0033: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-02-01 — 2025-02-28
# ⚠️ Ошибка 503 для станции GHCND:US1NJES0040 (2025-02-01 — 2025-02-28)
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-04-01 — 2025-04-30
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-05-01 — 2025-05-31
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-06-01 — 2025-06-30
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-07-01 — 2025-07-31
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-08-01 — 2025-08-31
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-09-01 — 2025-09-30
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-10-01 — 2025-10-31
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-11-01 — 2025-11-30
# 🔎 Скачиваем GHCND:US1NJES0040: 2025-12-01 — 2025-12-31
# 🔎 Скачиваем GHCND:US1NJHD0002: 2025-01-01 — 2025-01-31
# 🔎 Скачиваем GHCND:US1NJHD0002: 2025-02-01 — 2025-02-28
# 🔎 Скачиваем GHCND:US1NJHD0002: 2025-03-01 — 2025-03-31
# 🔎 Скачиваем GHCND:US1NJHD0002: 2025-04-01 — 2025-04-30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/4_/s5nq1m4x3x766j84pv1dwbz80000gn/T/ipykernel_22808/1768299234.py in <module>
#      52         }
#      53
# ---> 54         res = requests.get(url_data, params=params_data, headers=headers)
#      55
#      56         if res.status_code != 200:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             )
#     699             if is_new_proxy_conn and http_tunnel_required:
# --> 700                 self._prepare_proxy(conn)
#     701
#     702             # Make the request on the httplib connection object.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     994             conn.tls_in_tls_required = True
#     995
# --> 996         conn.connect()
#     997
#     998     def _new_conn(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     412             context.load_default_certs()
#     413
# --> 414         self.sock = ssl_wrap_socket(
#     415             sock=conn,
#     416             keyfile=self.key_file,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     447
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#     451         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     491
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#     495         return ssl_context.wrap_socket(sock)
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # SSLSocket class handles server_hostname encoding before it calls
#     500         # ctx._wrap_socket()
# --> 501         return self.sslsocket_class._create(
#     502             sock=sock,
#     503             server_side=server_side,
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         # non-blocking
#    1040                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041                     self.do_handshake()
#    1042             except (OSError, ValueError):
#    1043                 self.close()
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in do_handshake(self, block)
#    1308             if timeout == 0.0 and block:
#    1309                 self.settimeout(None)
# -> 1310             self._sslobj.do_handshake()
#    1311         finally:
#    1312             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
import pandas as pd

# --------------------------------------
# 1. Загружаем погодный датасет
# --------------------------------------

# Путь к твоему CSV с погодой
weather_path = "nyc_weather_2025.csv"

# Загружаем
df_weather = pd.read_csv(weather_path, parse_dates=["date"])

# Оставляем только Центральный парк
df_weather_citywide = df_weather[df_weather["station"] == "GHCND:USW00094728"].copy()
df_weather_citywide["date"] = pd.to_datetime(df_weather_citywide["date"]).dt.date

# Удаляем колонку station (она больше не нужна)
df_weather_citywide.drop(columns=["station"], inplace=True)

# Для проверки
print("✅ Погодный датасет:")
print(df_weather_citywide.head())

# --------------------------------------
# 2. Загружаем такси-датасет
# --------------------------------------

# Путь к твоему parquet-файлу
taxi_path = "green_tripdata_aggregated.csv"

df_taxi = pd.read_csv(taxi_path)

print("✅ Такси-датасет:")
print(df_taxi.head())

# --------------------------------------
# 3. Создаем колонку даты в такси-датасете
# --------------------------------------

# Если в твоем датасете есть pickup_hour:
if "pickup_date" in df_taxi.columns:
    # pickup_date может быть строкой вроде "2025-01-01 15"
    df_taxi["date"] = pd.to_datetime(df_taxi["pickup_date"]).dt.date

elif "pickup_datetime" in df_taxi.columns:
    # Если в датасете сохранился оригинальный datetime
    df_taxi["date"] = pd.to_datetime(df_taxi["pickup_datetime"]).dt.date

else:
    raise ValueError("Не нашел колонку pickup_hour или pickup_datetime в taxi-датасете!")

print("✅ Добавлена колонка date в такси-датасет:")
print(df_taxi[["pickup_hour", "date"]].head())

# --------------------------------------
# 4. Склеиваем два датасета
# --------------------------------------

df_merged = df_taxi.merge(
    df_weather_citywide,
    left_on="date",
    right_on="date",
    how="left"
)

print("✅ Итоговый склеенный датасет:")
print(df_merged.head())

# --------------------------------------
# 5. Сохраняем результат
# --------------------------------------

df_merged.to_parquet("nyc_taxi_weather_merged.parquet", index=False)
# или, если хочешь CSV:
# df_merged.to_csv("nyc_taxi_weather_merged.csv", index=False)

print("✅ Итоговый файл сохранен: nyc_taxi_weather_merged.parquet")
# Out:
# ✅ Погодный датасет:
#          date  AWND    PGTM  PRCP  SNOW  SNWD  TMAX  TMIN   WDF2   WDF5  WSF2  \
# 0  2025-01-01   3.7  1606.0   0.0   0.0   0.0  10.6   3.9  280.0  270.0   9.8
# 1  2025-01-02   4.3  1508.0   0.0   0.0   0.0   6.1   0.6  280.0  230.0   8.9
# 2  2025-01-03   3.5  1439.0   0.0   0.0   0.0   3.9  -0.5  230.0  230.0   6.7
# 3  2025-01-04   4.5  1302.0   0.0   0.0   0.0   0.6  -2.1  270.0  320.0   9.8
# 4  2025-01-05   3.8  1614.0   0.0   0.0   0.0   0.6  -2.1  310.0  310.0   8.1
#
#    WSF5  WT01  WT02  WT03  WT06  WT08
# 0  16.1   NaN   NaN   NaN   NaN   NaN
# 1  17.4   NaN   NaN   NaN   NaN   NaN
# 2  12.1   NaN   NaN   NaN   NaN   NaN
# 3  17.9   NaN   NaN   NaN   NaN   NaN
# 4  13.4   NaN   NaN   NaN   NaN   NaN
# ✅ Такси-датасет:
#    pickup_location_id pickup_date  pickup_hour  trip_time  \
# 0                 1.0  2022-01-01            4        NaN
# 1                 1.0  2022-01-01            5        NaN
# 2                 1.0  2022-01-01            7        NaN
# 3                 1.0  2022-01-01           10        NaN
# 4                 1.0  2022-01-01           11        NaN
#
#    base_passenger_fare  tolls  bcf  sales_tax  congestion_surcharge  \
# 0                  NaN    NaN  NaN        NaN                   0.0
# 1                  NaN    NaN  NaN        NaN                   0.0
# 2                  NaN    NaN  NaN        NaN                   0.0
# 3                  NaN    NaN  NaN        NaN                   0.0
# 4                  NaN    NaN  NaN        NaN                   0.0
#
#    airport_fee  ...  extra  mta_tax  tip_amount  tolls_amount  \
# 0          0.0  ...    0.0      0.0        0.00          0.00
# 1          0.0  ...    0.0      0.0       10.00          0.00
# 2          0.0  ...    0.0      0.0       11.03          0.00
# 3          0.0  ...    0.0      0.0        0.00         18.75
# 4          0.0  ...    0.0      0.0        2.50          0.00
#
#    improvement_surcharge  total_amount  Airport_fee  trip_type  \
# 0                    0.3         40.30          NaN        NaN
# 1                    0.3        105.30          NaN        NaN
# 2                    0.3        107.83          NaN        NaN
# 3                    0.3         98.05          NaN        NaN
# 4                    0.3        105.30          NaN        NaN
#
#    dropoff_location_id  ride_count
# 0                  1.0           1
# 1                  1.0           1
# 2                  1.0           2
# 3                  1.0           1
# 4                  1.0           2
#
# [5 rows x 29 columns]
# ✅ Добавлена колонка date в такси-датасет:
#    pickup_hour        date
# 0            4  2022-01-01
# 1            5  2022-01-01
# 2            7  2022-01-01
# 3           10  2022-01-01
# 4           11  2022-01-01
# ✅ Итоговый склеенный датасет:
#    pickup_location_id pickup_date  pickup_hour  trip_time  \
# 0                 1.0  2022-01-01            4        NaN
# 1                 1.0  2022-01-01            5        NaN
# 2                 1.0  2022-01-01            7        NaN
# 3                 1.0  2022-01-01           10        NaN
# 4                 1.0  2022-01-01           11        NaN
#
#    base_passenger_fare  tolls  bcf  sales_tax  congestion_surcharge  \
# 0                  NaN    NaN  NaN        NaN                   0.0
# 1                  NaN    NaN  NaN        NaN                   0.0
# 2                  NaN    NaN  NaN        NaN                   0.0
# 3                  NaN    NaN  NaN        NaN                   0.0
# 4                  NaN    NaN  NaN        NaN                   0.0
#
#    airport_fee  ...  TMIN  WDF2  WDF5  WSF2  WSF5  WT01  WT02  WT03  WT06  \
# 0          0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1          0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2          0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3          0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4          0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WT08
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 46 columns]
# ✅ Итоговый файл сохранен: nyc_taxi_weather_merged.parquet

# %%
df_merged.columns
# Out:
# Index(['pickup_location_id', 'pickup_date', 'pickup_hour', 'trip_time',
#        'base_passenger_fare', 'tolls', 'bcf', 'sales_tax',
#        'congestion_surcharge', 'airport_fee', 'tips', 'driver_pay',
#        'cbd_congestion_fee', 'VendorID', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'payment_type', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'Airport_fee', 'trip_type', 'dropoff_location_id', 'ride_count', 'date',
#        'AWND', 'PGTM', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN', 'WDF2', 'WDF5',
#        'WSF2', 'WSF5', 'WT01', 'WT02', 'WT03', 'WT06', 'WT08'],
#       dtype='object')

# %%
df_merged
# Out:
#         pickup_location_id pickup_date  pickup_hour  trip_time  \
# 0                      1.0  2022-01-01            4        NaN
# 1                      1.0  2022-01-01            5        NaN
# 2                      1.0  2022-01-01            7        NaN
# 3                      1.0  2022-01-01           10        NaN
# 4                      1.0  2022-01-01           11        NaN
# ...                    ...         ...          ...        ...
# 731722               265.0  2025-04-30           19        NaN
# 731723               265.0  2025-04-30           20     1427.0
# 731724               265.0  2025-04-30           21     1339.0
# 731725               265.0  2025-04-30           22        NaN
# 731726               265.0  2025-04-30           23      343.0
#
#         base_passenger_fare  tolls    bcf  sales_tax  congestion_surcharge  \
# 0                       NaN    NaN    NaN        NaN                   0.0
# 1                       NaN    NaN    NaN        NaN                   0.0
# 2                       NaN    NaN    NaN        NaN                   0.0
# 3                       NaN    NaN    NaN        NaN                   0.0
# 4                       NaN    NaN    NaN        NaN                   0.0
# ...                     ...    ...    ...        ...                   ...
# 731722                  NaN    NaN    NaN        NaN                   0.0
# 731723                23.55    0.0  0.585       2.08                   0.0
# 731724                24.56    0.0  0.550       0.00                   0.0
# 731725                  NaN    NaN    NaN        NaN                   0.0
# 731726                14.61    0.0  0.365       0.00                   0.0
#
#         airport_fee  ...  TMIN   WDF2   WDF5  WSF2  WSF5  WT01  WT02  WT03  \
# 0               0.0  ...   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 1               0.0  ...   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2               0.0  ...   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 3               0.0  ...   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 4               0.0  ...   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# ...             ...  ...   ...    ...    ...   ...   ...   ...   ...   ...
# 731722          NaN  ...  15.0  300.0  300.0   6.7  11.6   NaN   NaN   NaN
# 731723          0.0  ...  15.0  300.0  300.0   6.7  11.6   NaN   NaN   NaN
# 731724          0.0  ...  15.0  300.0  300.0   6.7  11.6   NaN   NaN   NaN
# 731725          NaN  ...  15.0  300.0  300.0   6.7  11.6   NaN   NaN   NaN
# 731726          0.0  ...  15.0  300.0  300.0   6.7  11.6   NaN   NaN   NaN
#
#         WT06  WT08
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
# ...      ...   ...
# 731722   NaN   NaN
# 731723   NaN   NaN
# 731724   NaN   NaN
# 731725   NaN   NaN
# 731726   NaN   NaN
#
# [731727 rows x 46 columns]

# %%
# Поля, которые хотим удалить
columns_to_drop = [
    "tips", 
    "tip_amount", 
    "airport_fee", 
    "Airport_fee",
    "tolls", 
    "tolls_amount", 
    "mta_tax",
    "bcf", 
    "improvement_surcharge", 
    "base_passenger_fare",
    "VendorID", 
    "trip_type", 
    "date", 
    "PGTM", 
    "WDF2", 
    "WDF5", 
    "WSF2", 
    "WSF5", 
    "WT02", 
    "WT06", 
    "WT08"
]

# Удаляем только те столбцы, которые реально есть в датафрейме
cols_existing = [col for col in columns_to_drop if col in df_taxi.columns]

print("Будут удалены столбцы:", cols_existing)

# Удаляем
df_taxi_cleaned = df_taxi.drop(columns=cols_existing)
# Out:
# Будут удалены столбцы: ['tips', 'tip_amount', 'airport_fee', 'Airport_fee', 'tolls', 'tolls_amount', 'mta_tax', 'bcf', 'improvement_surcharge', 'base_passenger_fare', 'VendorID', 'trip_type', 'date']

# %%
df_taxi_cleaned
# Out:
#         pickup_location_id pickup_date  pickup_hour  trip_time  sales_tax  \
# 0                      1.0  2022-01-01            4        NaN        NaN
# 1                      1.0  2022-01-01            5        NaN        NaN
# 2                      1.0  2022-01-01            7        NaN        NaN
# 3                      1.0  2022-01-01           10        NaN        NaN
# 4                      1.0  2022-01-01           11        NaN        NaN
# ...                    ...         ...          ...        ...        ...
# 731722               265.0  2025-04-30           19        NaN        NaN
# 731723               265.0  2025-04-30           20     1427.0       2.08
# 731724               265.0  2025-04-30           21     1339.0       0.00
# 731725               265.0  2025-04-30           22        NaN        NaN
# 731726               265.0  2025-04-30           23      343.0       0.00
#
#         congestion_surcharge  driver_pay  cbd_congestion_fee  passenger_count  \
# 0                        0.0         NaN                 NaN         3.000000
# 1                        0.0         NaN                 NaN         2.000000
# 2                        0.0         NaN                 NaN         2.000000
# 3                        0.0         NaN                 NaN         2.000000
# 4                        0.0         NaN                 NaN         1.500000
# ...                      ...         ...                 ...              ...
# 731722                   0.0         NaN                 0.0         1.666667
# 731723                   0.0      22.705                 0.0         1.000000
# 731724                   0.0      37.180                 0.0         1.000000
# 731725                   0.0         NaN                 0.0         0.666667
# 731726                   0.0      10.500                 0.0         1.000000
#
#         trip_distance  RatecodeID  payment_type  fare_amount     extra  \
# 0            0.000000    5.000000      1.000000    40.000000  0.000000
# 1            0.000000    5.000000      1.000000    95.000000  0.000000
# 2            0.000000    5.000000      1.000000    96.500000  0.000000
# 3            0.000000    5.000000      1.000000    79.000000  0.000000
# 4            0.000000    5.000000      1.000000   102.500000  0.000000
# ...               ...         ...           ...          ...       ...
# 731722       0.120000    5.000000      1.000000   119.396667  0.000000
# 731723       4.844000    1.800000      3.400000    12.000000  0.000000
# 731724       1.667500    5.000000      1.000000    95.750000  0.000000
# 731725       1.673333    3.333333      1.333333    31.266667  0.666667
# 731726       0.000000    5.000000      1.000000    52.500000  0.000000
#
#         total_amount  dropoff_location_id  ride_count
# 0             40.300             1.000000           1
# 1            105.300             1.000000           1
# 2            107.830             1.000000           2
# 3             98.050             1.000000           1
# 4            105.300             1.000000           2
# ...              ...                  ...         ...
# 731722       139.260           217.500000           4
# 731723        15.012           248.333333           9
# 731724       113.365           255.000000           6
# 731725        60.000           197.833333           6
# 731726        57.000           225.800000           5
#
# [731727 rows x 17 columns]

# %%
df_taxi_cleaned.to_parquet("nyc_taxi_weather_merged.parquet", index=False)
